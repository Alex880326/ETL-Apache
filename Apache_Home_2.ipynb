# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex880326/ETL-Apache/blob/main/Apache_Home_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Создание данных для таблицы
data = {'Id': [1, 2, 3, 4, 5],
        'Name': ['Joe', 'Henry', 'Sam', 'Max', 'Eve'],
        'Salary': [70, 80, 60, 90, 77],
        'ManagerId': [3, 4, 'null', 'null', 2]}

# Создание DataFrame из данных
df = pd.DataFrame(data)

# Сохранение DataFrame в файл CSV
df.to_csv('employees.csv', index=False)

# %%
df
# Out:
#    Id   Name  Salary ManagerId
# 0   1    Joe      70         3
# 1   2  Henry      80         4
# 2   3    Sam      60      null
# 3   4    Max      90      null
# 4   5    Eve      77         2

# %%
df.Salary.max()
# Out:
# 90
